# %% [markdown]
# ## **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast #to process trees of the Python abstract syntax grammar

# %% [markdown]
# ## **Import Dataset**

# %% [markdown]
# ### **2018**

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
frames = [df1, df2, df3, df4]

df = pd.concat(frames)
df.head()
# Out:
#          Opening  Opening.1                    Title  \
# 0  J A N U A R Y          5  Insidious: The Last Key
# 1  J A N U A R Y          5         The Strange Ones
# 2  J A N U A R Y         12             The Commuter
# 3  J A N U A R Y         12               Proud Mary
# 4  J A N U A R Y         12         Acts of Violence
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2      Lionsgate / StudioCanal / The Picture Company
# 3                                        Screen Gems
# 4                                 Lionsgate Premiere
#
#                                        Cast and crew Ref.
# 0  Adam Robitel (director); Leigh Whannell (scree...  [2]
# 1  Christopher Radcliff (director/screenplay); La...  [3]
# 2  Jaume Collet-Serra (director); Byron Willinger...  [4]
# 3  Babak Najafi (director); John S. Newman, Chris...  [5]
# 4  Brett Donowho (director); Nicolas Aaron Mezzan...  [6]

# %%
#
! pip install -q tmdbv3api

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '0e08f345ffc26f23f3d54b0f9afb65b7'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()

# this function will pass in the title of the movies then retrieve the genre of the movie from IMDB
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x) #the title will be searched in the tmdb_movie
    movie_id = result[0].id #we will match the "id" with the "title"
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key)) #we will get the result from the IMDb data
    data_json = response.json() #we will then convert it to a json file
    if data_json['genres']: #in the json file we will only need to extract the "genre"
        genre_str = " "
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name']) #we will then add the "genre" to the empty genre list we created above
        return genre_str.join(genres)
    else:
        np.NaN # we will return the results but if we don't find anything we will consider it as a missing value

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df.head(3)
# Out:
#          Opening  Opening.1                    Title  \
# 0  J A N U A R Y          5  Insidious: The Last Key
# 1  J A N U A R Y          5         The Strange Ones
# 2  J A N U A R Y         12             The Commuter
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2      Lionsgate / StudioCanal / The Picture Company
#
#                                        Cast and crew Ref.  \
# 0  Adam Robitel (director); Leigh Whannell (scree...  [2]
# 1  Christopher Radcliff (director/screenplay); La...  [3]
# 2  Jaume Collet-Serra (director); Byron Willinger...  [4]
#
#                     genres
# 0          Horror Thriller
# 1           Thriller Drama
# 2  Action Thriller Mystery

# %%
df_2018 = df[['Title','Cast and crew','genres']]
df_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Christopher Radcliff (director/screenplay); La...
# 2             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
# 3               Proud Mary  Babak Najafi (director); John S. Newman, Chris...
# 4         Acts of Violence  Brett Donowho (director); Nicolas Aaron Mezzan...
#
#                     genres
# 0          Horror Thriller
# 1           Thriller Drama
# 2  Action Thriller Mystery
# 3    Thriller Action Crime
# 4    Action Crime Thriller

# %%
df_2018.shape
# Out:
# (249, 3)

# %% [markdown]
# ## **Directors**

# %%
pd.set_option('display.max_colwidth',250)
df['Cast and crew'].head(3)
# Out:
# 0                                 Adam Robitel (director); Leigh Whannell (screenplay); Lin Shaye, Angus Sampson, Leigh Whannell, Spencer Locke, Caitlin Gerard, Bruce Davison
# 1    Christopher Radcliff (director/screenplay); Lauren Wolkstein (director); Alex Pettyfer, James Freedson-Jackson, Emily Althaus, Gene Jones, Owen Campbell, Tobias Campbell
# 2               Jaume Collet-Serra (director); Byron Willinger, Philip de Blasi, Ryan Engle (screenplay); Liam Neeson, Vera Farmiga, Patrick Wilson, Jonathan Banks, Sam Neill
# Name: Cast and crew, dtype: object

# %%
def get_director(x):
    # Split the row into segments by ";"
    segments = x.split(";")

    # Step 1: Prioritize "(director)"
    for segment in segments:
        if "(director)" in segment:
            return segment.split(" (director)")[0].strip()

    # Step 2: Check for "(directors)" if "(director)" is not found
    for segment in segments:
        if "(directors)" in segment:
            return segment.split(" (directors)")[0].strip()

    # Step 3a: Check for "(director/screenplay)" if neither "(director)" nor "(directors)" is found
    for segment in segments:
        if "(director/screenplay)" in segment:
            return segment.split(" (director/screenplay)")[0].strip()

    # Step 3b: Check for "(directors/screenplay)" if neither "(director)" nor "(directors)" is found
    for segment in segments:
        if "(directors/screenplay)" in segment:
            return segment.split(" (directors/screenplay)")[0].strip()

    # Step 3c: Check for "(directors/screenplay)" if neither "(director)" nor "(directors)" is found
    for segment in segments:
        if "(director/screenplay/narrator))" in segment:
            return segment.split("(director/screenplay/narrator)	")[0].strip()

    # Step 4: If no valid director-related keywords are found, return NaN
    return np.NaN

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
df_2018.head()
# Out:
# <ipython-input-12-82c2343e822a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
#                      Title  \
# 0  Insidious: The Last Key
# 1         The Strange Ones
# 2             The Commuter
# 3               Proud Mary
# 4         Acts of Violence
#
#                                                                                                                                                                Cast and crew  \
# 0                               Adam Robitel (director); Leigh Whannell (screenplay); Lin Shaye, Angus Sampson, Leigh Whannell, Spencer Locke, Caitlin Gerard, Bruce Davison
# 1  Christopher Radcliff (director/screenplay); Lauren Wolkstein (director); Alex Pettyfer, James Freedson-Jackson, Emily Althaus, Gene Jones, Owen Campbell, Tobias Campbell
# 2             Jaume Collet-Serra (director); Byron Willinger, Philip de Blasi, Ryan Engle (screenplay); Liam Neeson, Vera Farmiga, Patrick Wilson, Jonathan Banks, Sam Neill
# 3                     Babak Najafi (director); John S. Newman, Christian Swegal, Steve Antin (screenplay); Taraji P. Henson, Jahi Di'Allo Winston, Billy Brown, Danny Glover
# 4           Brett Donowho (director); Nicolas Aaron Mezzanatto (screenplay); Bruce Willis, Cole Hauser, Shawn Ashmore, Ashton Holmes, Melissa Bolona, Sophia Bush, Mike Epps
#
#                     genres       director_name
# 0          Horror Thriller        Adam Robitel
# 1           Thriller Drama    Lauren Wolkstein
# 2  Action Thriller Mystery  Jaume Collet-Serra
# 3    Thriller Action Crime        Babak Najafi
# 4    Action Crime Thriller       Brett Donowho

# %%
df_2018[df_2018['director_name'].isna()]
# Out:
#                                     Title  \
# 24                          Black Panther
# 5   Hotel Transylvania 3: Summer Vacation
# 61                        Fahrenheit 11/9
# 64                           Night School
#
#                                                                                                                                                                                                                                                 Cast and crew  \
# 24  Ryan Coogler (director/​screenplay); Joe Robert Cole (screenplay); Chadwick Boseman, Michael B. Jordan, Lupita Nyong'o, Danai Gurira, Martin Freeman, Daniel Kaluuya, Letitia Wright, Winston Duke, Sterling K. Brown, Angela Bassett, Forest Whitaker...
# 5   Genndy Tartakovsky (director/screenplay[119]); Michael McCullers (screenplay); Adam Sandler, Andy Samberg, Selena Gomez, Kevin James, David Spade, Steve Buscemi, Keegan-Michael Key, Molly Shannon, Fran Drescher, Kathryn Hahn, Jim Gaffigan, Mel Br...
# 61                                                                                                                                                                                                               Michael Moore (director/screenplay/narrator)
# 64                                                             Malcolm D. Lee (director[177]); Kevin Hart, Harry Ratchford, Joey Wells, Matt Kellard, Nicholas Stoller,[178] John Hamburg (screenplay); Kevin Hart, Tiffany Haddish, Rob Riggle, Romany Malco
#
#                               genres director_name
# 24  Action Adventure Science Fiction           NaN
# 5    Animation Comedy Family Fantasy           NaN
# 61                       Documentary           NaN
# 64                            Comedy           NaN

# %% [markdown]
# ## **Actors**

# %%
def get_actor1(x):
    # Remove parts that include "(director)" or "(screenplay)" or "(director/screenplay)"
    cleaned = "; ".join([part for part in x.split("; ") if not any(keyword in part for keyword in ["(director)", "(screenplay)", "(director/screenplay)"])])

    # Extract the first actor from the cleaned string
    if ", " in cleaned:
        return cleaned.split(", ")[0].strip()
    else:
        return np.NaN  # Return NaN if no actors are found

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

df_2018
# Out:
# <ipython-input-15-2b382c5e7b0d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
#                       Title  \
# 0   Insidious: The Last Key
# 1          The Strange Ones
# 2              The Commuter
# 3                Proud Mary
# 4          Acts of Violence
# ..                      ...
# 58               Second Act
# 59          Holmes & Watson
# 60                     Vice
# 61      On the Basis of Sex
# 62                Destroyer
#
#                                                                                                                                                                    Cast and crew  \
# 0                                   Adam Robitel (director); Leigh Whannell (screenplay); Lin Shaye, Angus Sampson, Leigh Whannell, Spencer Locke, Caitlin Gerard, Bruce Davison
# 1      Christopher Radcliff (director/screenplay); Lauren Wolkstein (director); Alex Pettyfer, James Freedson-Jackson, Emily Althaus, Gene Jones, Owen Campbell, Tobias Campbell
# 2                 Jaume Collet-Serra (director); Byron Willinger, Philip de Blasi, Ryan Engle (screenplay); Liam Neeson, Vera Farmiga, Patrick Wilson, Jonathan Banks, Sam Neill
# 3                         Babak Najafi (director); John S. Newman, Christian Swegal, Steve Antin (screenplay); Taraji P. Henson, Jahi Di'Allo Winston, Billy Brown, Danny Glover
# 4               Brett Donowho (director); Nicolas Aaron Mezzanatto (screenplay); Bruce Willis, Cole Hauser, Shawn Ashmore, Ashton Holmes, Melissa Bolona, Sophia Bush, Mike Epps
# ..                                                                                                                                                                           ...
# 58                  Peter Segal (director); Justin Zackham, Elaine Goldsmith-Thomas (screenplay); Jennifer Lopez, Leah Remini, Vanessa Hudgens, Treat Williams, Milo Ventimiglia
# 59                                        Etan Cohen (director/screenplay); Will Ferrell, John C. Reilly, Rebecca Hall, Rob Brydon, Kelly Macdonald, Steve Coogan, Ralph Fiennes
# 60                                   Adam McKay (director/screenplay); Christian Bale, Amy Adams, Steve Carell, Tyler Perry, Alison Pill, Lily Rabe, Jesse Plemons, Sam Rockwell
# 61                                               Mimi Leder (director); Daniel Stiepleman (screenplay); Felicity Jones, Armie Hammer, Justin Theroux, Sam Waterston, Kathy Bates
# 62  Karyn Kusama (director); Phil Hay, Matt Manfredi (screenplay); Nicole Kidman, Sebastian Stan, Toby Kebbell, Tatiana Maslany, Bradley Whitford, Jade Pettyjohn, Scoot McNairy
#
#                                        genres       director_name  \
# 0                             Horror Thriller        Adam Robitel
# 1                              Thriller Drama    Lauren Wolkstein
# 2                     Action Thriller Mystery  Jaume Collet-Serra
# 3                       Thriller Action Crime        Babak Najafi
# 4                       Action Crime Thriller       Brett Donowho
# ..                                        ...                 ...
# 58                             Romance Comedy         Peter Segal
# 59                       Comedy Mystery Crime          Etan Cohen
# 60  Thriller Science Fiction Action Adventure          Adam McKay
# 61                              Drama History          Mimi Leder
# 62                Thriller Crime Drama Action        Karyn Kusama
#
#         actor_1_name
# 0          Lin Shaye
# 1      Alex Pettyfer
# 2        Liam Neeson
# 3   Taraji P. Henson
# 4       Bruce Willis
# ..               ...
# 58    Jennifer Lopez
# 59      Will Ferrell
# 60    Christian Bale
# 61    Felicity Jones
# 62     Nicole Kidman
#
# [249 rows x 5 columns]

# %%
df_2018[df_2018['actor_1_name'].isna()]
# Out:
#                               Title  \
# 4                           Whitney
# 28             A Prayer Before Dawn
# 61                  Fahrenheit 11/9
# 2   The Great Buster: A Celebration
#
#                                                                                    Cast and crew  \
# 4                                         Kevin Macdonald (director/screenplay); Whitney Houston
# 28  Jean-Stéphane Sauvaire (director); Jonathan Hirschbein, Nick Saltrese (screenplay); Joe Cole
# 61                                                  Michael Moore (director/screenplay/narrator)
# 2                                                        Peter Bogdanovich (director/screenplay)
#
#                 genres           director_name actor_1_name
# 4    Music Documentary         Kevin Macdonald          NaN
# 28  Drama Action Crime  Jean-Stéphane Sauvaire          NaN
# 61         Documentary                     NaN          NaN
# 2   Documentary Comedy       Peter Bogdanovich          NaN

# %%
def get_actor2(x):
    # Remove parts that include "(director)" or "(screenplay)" or "(director/screenplay)"
    cleaned = "; ".join([part for part in x.split("; ") if not any(keyword in part for keyword in ["(director)", "(screenplay)", "(director/screenplay)"])])

    # Extract the second actor from the cleaned string
    actors = cleaned.split(", ")
    if len(actors) > 1:  # Check if there's a second actor
        return actors[1].strip()
    else:
        return np.NaN

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

df_2018.head()
# Out:
# <ipython-input-18-3546b97b3937>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
#                      Title  \
# 0  Insidious: The Last Key
# 1         The Strange Ones
# 2             The Commuter
# 3               Proud Mary
# 4         Acts of Violence
#
#                                                                                                                                                                Cast and crew  \
# 0                               Adam Robitel (director); Leigh Whannell (screenplay); Lin Shaye, Angus Sampson, Leigh Whannell, Spencer Locke, Caitlin Gerard, Bruce Davison
# 1  Christopher Radcliff (director/screenplay); Lauren Wolkstein (director); Alex Pettyfer, James Freedson-Jackson, Emily Althaus, Gene Jones, Owen Campbell, Tobias Campbell
# 2             Jaume Collet-Serra (director); Byron Willinger, Philip de Blasi, Ryan Engle (screenplay); Liam Neeson, Vera Farmiga, Patrick Wilson, Jonathan Banks, Sam Neill
# 3                     Babak Najafi (director); John S. Newman, Christian Swegal, Steve Antin (screenplay); Taraji P. Henson, Jahi Di'Allo Winston, Billy Brown, Danny Glover
# 4           Brett Donowho (director); Nicolas Aaron Mezzanatto (screenplay); Bruce Willis, Cole Hauser, Shawn Ashmore, Ashton Holmes, Melissa Bolona, Sophia Bush, Mike Epps
#
#                     genres       director_name      actor_1_name  \
# 0          Horror Thriller        Adam Robitel         Lin Shaye
# 1           Thriller Drama    Lauren Wolkstein     Alex Pettyfer
# 2  Action Thriller Mystery  Jaume Collet-Serra       Liam Neeson
# 3    Thriller Action Crime        Babak Najafi  Taraji P. Henson
# 4    Action Crime Thriller       Brett Donowho      Bruce Willis
#
#              actor_2_name
# 0           Angus Sampson
# 1  James Freedson-Jackson
# 2            Vera Farmiga
# 3    Jahi Di'Allo Winston
# 4             Cole Hauser

# %%
df_2018[df_2018['actor_2_name'].isna()]
# Out:
#                               Title  \
# 4                           Whitney
# 28             A Prayer Before Dawn
# 61                  Fahrenheit 11/9
# 2   The Great Buster: A Celebration
#
#                                                                                    Cast and crew  \
# 4                                         Kevin Macdonald (director/screenplay); Whitney Houston
# 28  Jean-Stéphane Sauvaire (director); Jonathan Hirschbein, Nick Saltrese (screenplay); Joe Cole
# 61                                                  Michael Moore (director/screenplay/narrator)
# 2                                                        Peter Bogdanovich (director/screenplay)
#
#                 genres           director_name actor_1_name actor_2_name
# 4    Music Documentary         Kevin Macdonald          NaN          NaN
# 28  Drama Action Crime  Jean-Stéphane Sauvaire          NaN          NaN
# 61         Documentary                     NaN          NaN          NaN
# 2   Documentary Comedy       Peter Bogdanovich          NaN          NaN

# %%
def get_actor3(x):
    # Step 1: Split the string to remove everything before "screenplay); "
    parts = x.split("screenplay); ")

    # Step 2: Check if there are actors after the screenplay/director section
    if len(parts) > 1:
        actors = parts[-1].split(", ")  # Extract the actors part and split by commas
    else:
        return np.NaN  # Return NaN if no actors are present

    # Step 3: Check if there are at least three actors
    if len(actors) >= 3:
        return actors[2].strip()  # Return the third actor
    else:
        return np.NaN  # Return NaN if there are fewer than three actors

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

df_2018.head()
# Out:
#                      Title  \
# 0  Insidious: The Last Key
# 1         The Strange Ones
# 2             The Commuter
# 3               Proud Mary
# 4         Acts of Violence
#
#                                                                                                                                                                Cast and crew  \
# 0                               Adam Robitel (director); Leigh Whannell (screenplay); Lin Shaye, Angus Sampson, Leigh Whannell, Spencer Locke, Caitlin Gerard, Bruce Davison
# 1  Christopher Radcliff (director/screenplay); Lauren Wolkstein (director); Alex Pettyfer, James Freedson-Jackson, Emily Althaus, Gene Jones, Owen Campbell, Tobias Campbell
# 2             Jaume Collet-Serra (director); Byron Willinger, Philip de Blasi, Ryan Engle (screenplay); Liam Neeson, Vera Farmiga, Patrick Wilson, Jonathan Banks, Sam Neill
# 3                     Babak Najafi (director); John S. Newman, Christian Swegal, Steve Antin (screenplay); Taraji P. Henson, Jahi Di'Allo Winston, Billy Brown, Danny Glover
# 4           Brett Donowho (director); Nicolas Aaron Mezzanatto (screenplay); Bruce Willis, Cole Hauser, Shawn Ashmore, Ashton Holmes, Melissa Bolona, Sophia Bush, Mike Epps
#
#                     genres       director_name      actor_1_name  \
# 0          Horror Thriller        Adam Robitel         Lin Shaye
# 1           Thriller Drama    Lauren Wolkstein     Alex Pettyfer
# 2  Action Thriller Mystery  Jaume Collet-Serra       Liam Neeson
# 3    Thriller Action Crime        Babak Najafi  Taraji P. Henson
# 4    Action Crime Thriller       Brett Donowho      Bruce Willis
#
#              actor_2_name    actor_3_name
# 0           Angus Sampson  Leigh Whannell
# 1  James Freedson-Jackson   Emily Althaus
# 2            Vera Farmiga  Patrick Wilson
# 3    Jahi Di'Allo Winston     Billy Brown
# 4             Cole Hauser   Shawn Ashmore

# %%
df_2018[df_2018['actor_3_name'].isna()]
# Out:
#                               Title  \
# 14                A Fantastic Woman
# 19                          Pad Man
# 19                            Kings
# 38                     Action Point
# 39                           Adrift
# 44        Won't You Be My Neighbor?
# 53                           Damsel
# 4                           Whitney
# 23                 Never Goin' Back
# 28             A Prayer Before Dawn
# 31                            Alpha
# 39                        Searching
# 44              Destination Wedding
# 61                  Fahrenheit 11/9
# 62                      Love, Gilda
# 2   The Great Buster: A Celebration
# 9                  After Everything
# 12         Can You Ever Forgive Me?
# 40        Ralph Breaks the Internet
#
#                                                                                                                                                                                                                                            Cast and crew  \
# 14                                                                                                                                               Sebastián Lelio (director/screenplay); Gonzalo Maza (screenplay); Daniela Vega, Francisco Reyes Morandé
# 19                                                                                                                                                              R. Balki (director/screenplay); Swanand Kirkire (screenplay); Akshay Kumar, Radhika Apte
# 19                                                                                                                                                                                  Deniz Gamze Ergüven (director/screenplay); Halle Berry, Daniel Craig
# 38                                                                                                                                                    Tim Kirkby (director); John Altschuler, Dave Krinsky (screenplay); Johnny Knoxville, Chris Pontius
# 39                                                                                                                          Baltasar Kormákur (director); Aaron Kandell, Jordan Kandell, David Branson Smith (screenplay); Shailene Woodley, Sam Claflin
# 44                                                                                                                                Morgan Neville (director); Fred Rogers, François Clemmons, Yo-Yo Ma, Joe Negri, David Newell, Tom Junod, Joanne Rogers
# 53                                                                                                                                                                David Zellner, Nathan Zellner (directors/screenplay); Robert Pattinson, Mia Wasikowska
# 4                                                                                                                                                                                                 Kevin Macdonald (director/screenplay); Whitney Houston
# 23                                                                                                                                                                               Augustine Frizzell (director/screenplay); Maia Mitchell, Camila Morrone
# 28                                                                                                                                                          Jean-Stéphane Sauvaire (director); Jonathan Hirschbein, Nick Saltrese (screenplay); Joe Cole
# 31                                                                                                                                   Albert Hughes (director); Daniele Sebastian Wiedenhaupt (screenplay); Kodi Smit-McPhee, Jóhannes Haukur Jóhannesson
# 39                                                                                                                                                              Aneesh Chaganty (director/screenplay); Sev Ohanian (screenplay); John Cho, Debra Messing
# 44                                                                                                                                                                                        Victor Levin (director/screenplay); Winona Ryder, Keanu Reeves
# 61                                                                                                                                                                                                          Michael Moore (director/screenplay/narrator)
# 62  Lisa D'Apolito (director); Gilda Radner, Amy Poehler, Melissa McCarthy, Bill Hader, Maya Rudolph, Lorne Michaels, Jordan Walker-Pearlman, Cecily Strong, Martin Short, Laraine Newman, Chevy Chase, Paul Shaffer, Stephen Schwartz, Andrew Alexander
# 2                                                                                                                                                                                                                Peter Bogdanovich (director/screenplay)
# 9                                                                                       Hannah Marks, Joey Power (directors/screenplay), Jeremy Allen White, Maika Monroe, DeRon Horton, Sasha Lane, Dean Winters, Joe Keery, Gina Gershon, Marisa Tomei
# 12                                                                                                                                           Marielle Heller (director); Nicole Holofcener, Jeff Whitty (screenplay); Melissa McCarthy, Richard E. Grant
# 40                       Rich Moore (director); Phil Johnston (director/screenplay[220]); Pamela Ribon (screenplay[220]); John C. Reilly, Sarah Silverman, Gal Gadot, Jane Lynch, Jack McBrayer, Alan Tudyk, Alfred Molina, Ed O'Neill, Taraji P. Henson
#
#                                genres                  director_name  \
# 14                              Drama                Sebastián Lelio
# 19                       Comedy Drama                       R. Balki
# 19                Romance Drama Crime            Deniz Gamze Ergüven
# 38                             Comedy                     Tim Kirkby
# 39         Thriller Romance Adventure              Baltasar Kormákur
# 44                        Documentary                 Morgan Neville
# 53           Fantasy Action Adventure  David Zellner, Nathan Zellner
# 4                   Music Documentary                Kevin Macdonald
# 23                             Comedy             Augustine Frizzell
# 28                 Drama Action Crime         Jean-Stéphane Sauvaire
# 31                    Adventure Drama                  Albert Hughes
# 39             Drama Mystery Thriller                Aneesh Chaganty
# 44               Romance Comedy Drama                   Victor Levin
# 61                        Documentary                            NaN
# 62                        Documentary                 Lisa D'Apolito
# 2                  Documentary Comedy              Peter Bogdanovich
# 9                       Romance Drama       Hannah Marks, Joey Power
# 12                 Drama Crime Comedy                Marielle Heller
# 40  Family Animation Comedy Adventure                     Rich Moore
#
#                                                                                 actor_1_name  \
# 14                                                                              Daniela Vega
# 19                                                                              Akshay Kumar
# 19                                                                               Halle Berry
# 38                                                                          Johnny Knoxville
# 39                                                                          Shailene Woodley
# 44                                                                               Fred Rogers
# 53                                                                             David Zellner
# 4                                                                                        NaN
# 23                                                                             Maia Mitchell
# 28                                                                                       NaN
# 31                                                                          Kodi Smit-McPhee
# 39                                                                                  John Cho
# 44                                                                              Winona Ryder
# 61                                                                                       NaN
# 62                                                                              Gilda Radner
# 2                                                                                        NaN
# 9                                                                               Hannah Marks
# 12                                                                          Melissa McCarthy
# 40  Phil Johnston (director/screenplay[220]); Pamela Ribon (screenplay[220]); John C. Reilly
#
#                                                actor_2_name actor_3_name
# 14                                  Francisco Reyes Morandé          NaN
# 19                                             Radhika Apte          NaN
# 19                                             Daniel Craig          NaN
# 38                                            Chris Pontius          NaN
# 39                                              Sam Claflin          NaN
# 44                                        François Clemmons          NaN
# 53  Nathan Zellner (directors/screenplay); Robert Pattinson          NaN
# 4                                                       NaN          NaN
# 23                                           Camila Morrone          NaN
# 28                                                      NaN          NaN
# 31                              Jóhannes Haukur Jóhannesson          NaN
# 39                                            Debra Messing          NaN
# 44                                             Keanu Reeves          NaN
# 61                                                      NaN          NaN
# 62                                              Amy Poehler          NaN
# 2                                                       NaN          NaN
# 9                         Joey Power (directors/screenplay)          NaN
# 12                                         Richard E. Grant          NaN
# 40                                          Sarah Silverman          NaN

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['combination'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']
new_df18.head()
# Out:
#         director_name      actor_1_name            actor_2_name  \
# 0        Adam Robitel         Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein     Alex Pettyfer  James Freedson-Jackson
# 2  Jaume Collet-Serra       Liam Neeson            Vera Farmiga
# 3        Babak Najafi  Taraji P. Henson    Jahi Di'Allo Winston
# 4       Brett Donowho      Bruce Willis             Cole Hauser
#
#      actor_3_name                   genres              movie_title  \
# 0  Leigh Whannell          Horror Thriller  insidious: the last key
# 1   Emily Althaus           Thriller Drama         the strange ones
# 2  Patrick Wilson  Action Thriller Mystery             the commuter
# 3     Billy Brown    Thriller Action Crime               proud mary
# 4   Shawn Ashmore    Action Crime Thriller         acts of violence
#
#                                                                             combination
# 0                   Lin Shaye Angus Sampson Leigh Whannell Adam Robitel Horror Thriller
# 1    Alex Pettyfer James Freedson-Jackson Emily Althaus Lauren Wolkstein Thriller Drama
# 2    Liam Neeson Vera Farmiga Patrick Wilson Jaume Collet-Serra Action Thriller Mystery
# 3  Taraji P. Henson Jahi Di'Allo Winston Billy Brown Babak Najafi Thriller Action Crime
# 4            Bruce Willis Cole Hauser Shawn Ashmore Brett Donowho Action Crime Thriller

# %% [markdown]
# ### **2019**

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]


frames = [df1, df2, df3, df4]

df_b = pd.concat(frames)
df_b.head()
# Out:
#          Opening Opening.1             Title  \
# 0  J A N U A R Y         4       Escape Room
# 1  J A N U A R Y         4        Rust Creek
# 2  J A N U A R Y         4  American Hangman
# 3  J A N U A R Y        11  A Dog's Way Home
# 4  J A N U A R Y        11        The Upside
#
#                   Production company  \
# 0  Columbia Pictures / Original Film
# 1     IFC Films / Lunacy Productions
# 2        Hangman Justice Productions
# 3                  Columbia Pictures
# 4                  STX Entertainment
#
#                                                                                                                                                                     Cast and crew  \
# 0  Adam Robitel (director); Bragi F. Schut, Maria Melnik (screenplay); Taylor Russell, Logan Miller, Deborah Ann Woll, Tyler Labine, Jay Ellis, Nik Dodani, Yorick van Wageningen
# 1                                                                 Jen McGowan (director); Julie Lipson (screenplay); Hermione Corfield, Jay Paulson, Sean O'Bryan, Micah Hauptman
# 2                                                                  Wilson Coneybeare (director/screenplay); Donald Sutherland, Vincent Kartheiser, Oliver Dennis, Paul Braunstein
# 3               Charles Martin Smith (director); W. Bruce Cameron (screenplay); Bryce Dallas Howard, Edward James Olmos, Alexandra Shipp, Ashley Judd, Jonah Haur-King, Wes Studi
# 4                                                                                    Neil Burger (director); Jon Hartmere (screenplay); Bryan Cranston, Kevin Hart, Nicole Kidman
#
#   Ref.
# 0  [2]
# 1  [3]
# 2  [4]
# 3  [5]
# 4  [6]

# %%
df_b['genres'] = df_b['Title'].map(lambda x: get_genre(str(x)))
df_b.head(3)
# Out:
#          Opening Opening.1             Title  \
# 0  J A N U A R Y         4       Escape Room
# 1  J A N U A R Y         4        Rust Creek
# 2  J A N U A R Y         4  American Hangman
#
#                   Production company  \
# 0  Columbia Pictures / Original Film
# 1     IFC Films / Lunacy Productions
# 2        Hangman Justice Productions
#
#                                                                                                                                                                     Cast and crew  \
# 0  Adam Robitel (director); Bragi F. Schut, Maria Melnik (screenplay); Taylor Russell, Logan Miller, Deborah Ann Woll, Tyler Labine, Jay Ellis, Nik Dodani, Yorick van Wageningen
# 1                                                                 Jen McGowan (director); Julie Lipson (screenplay); Hermione Corfield, Jay Paulson, Sean O'Bryan, Micah Hauptman
# 2                                                                  Wilson Coneybeare (director/screenplay); Donald Sutherland, Vincent Kartheiser, Oliver Dennis, Paul Braunstein
#
#   Ref.                       genres
# 0  [2]      Horror Thriller Mystery
# 1  [3]  Thriller Drama Action Crime
# 2  [4]                     Thriller

# %%
df_2019 = df_b[['Title','Cast and crew','genres']]
df_2019.head()
# Out:
#               Title  \
# 0       Escape Room
# 1        Rust Creek
# 2  American Hangman
# 3  A Dog's Way Home
# 4        The Upside
#
#                                                                                                                                                                     Cast and crew  \
# 0  Adam Robitel (director); Bragi F. Schut, Maria Melnik (screenplay); Taylor Russell, Logan Miller, Deborah Ann Woll, Tyler Labine, Jay Ellis, Nik Dodani, Yorick van Wageningen
# 1                                                                 Jen McGowan (director); Julie Lipson (screenplay); Hermione Corfield, Jay Paulson, Sean O'Bryan, Micah Hauptman
# 2                                                                  Wilson Coneybeare (director/screenplay); Donald Sutherland, Vincent Kartheiser, Oliver Dennis, Paul Braunstein
# 3               Charles Martin Smith (director); W. Bruce Cameron (screenplay); Bryce Dallas Howard, Edward James Olmos, Alexandra Shipp, Ashley Judd, Jonah Haur-King, Wes Studi
# 4                                                                                    Neil Burger (director); Jon Hartmere (screenplay); Bryan Cranston, Kevin Hart, Nicole Kidman
#
#                         genres
# 0      Horror Thriller Mystery
# 1  Thriller Drama Action Crime
# 2                     Thriller
# 3       Drama Adventure Family
# 4                 Comedy Drama

# %%
df_2019.shape
# Out:
# (250, 3)

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(x))
df_2019.head()
# Out:
# <ipython-input-31-3fbe135edb60>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(x))
#               Title  \
# 0       Escape Room
# 1        Rust Creek
# 2  American Hangman
# 3  A Dog's Way Home
# 4        The Upside
#
#                                                                                                                                                                     Cast and crew  \
# 0  Adam Robitel (director); Bragi F. Schut, Maria Melnik (screenplay); Taylor Russell, Logan Miller, Deborah Ann Woll, Tyler Labine, Jay Ellis, Nik Dodani, Yorick van Wageningen
# 1                                                                 Jen McGowan (director); Julie Lipson (screenplay); Hermione Corfield, Jay Paulson, Sean O'Bryan, Micah Hauptman
# 2                                                                  Wilson Coneybeare (director/screenplay); Donald Sutherland, Vincent Kartheiser, Oliver Dennis, Paul Braunstein
# 3               Charles Martin Smith (director); W. Bruce Cameron (screenplay); Bryce Dallas Howard, Edward James Olmos, Alexandra Shipp, Ashley Judd, Jonah Haur-King, Wes Studi
# 4                                                                                    Neil Burger (director); Jon Hartmere (screenplay); Bryan Cranston, Kevin Hart, Nicole Kidman
#
#                         genres         director_name
# 0      Horror Thriller Mystery          Adam Robitel
# 1  Thriller Drama Action Crime           Jen McGowan
# 2                     Thriller     Wilson Coneybeare
# 3       Drama Adventure Family  Charles Martin Smith
# 4                 Comedy Drama           Neil Burger

# %%
df_2019[df_2019['director_name'].isna()]
# Out:
#                            Title  \
# 34                   Wonder Park
# 35  The Professor and the Madman
# 41              The Tomorrow Man
#
#                                                                                                                                                                                         Cast and crew  \
# 34                              Josh Appelbaum, Andre Nemec (screenplay); Brianna Denski, Ken Hudson Campbell, Matthew Broderick, Jennifer Garner, Kenan Thompson, Ken Jeong, Mila Kunis, John Oliver
# 35  P.B. Shemran (director, screenplay); Todd Komarnicki (screenplay); Mel Gibson, Sean Penn, Natalie Dormer, Eddie Marsan, Jennifer Ehle, David O'Hara, Ioan Gruffudd, Stephen Dillane, Steve Coogan
# 41                                                                           Noble Jones (director, screenplay); John Lithgow, Blythe Danner, Derek Cecil, Katie Aselton, Sophie Thatcher, Eve Harlow
#
#                                        genres director_name
# 34  Comedy Animation Adventure Family Fantasy           NaN
# 35             History Drama Mystery Thriller           NaN
# 41                              Drama Romance           NaN

# %% [markdown]
# ## **Actors**

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

df_2019.head()
# Out:
# <ipython-input-33-9651f6cb0933>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
#               Title  \
# 0       Escape Room
# 1        Rust Creek
# 2  American Hangman
# 3  A Dog's Way Home
# 4        The Upside
#
#                                                                                                                                                                     Cast and crew  \
# 0  Adam Robitel (director); Bragi F. Schut, Maria Melnik (screenplay); Taylor Russell, Logan Miller, Deborah Ann Woll, Tyler Labine, Jay Ellis, Nik Dodani, Yorick van Wageningen
# 1                                                                 Jen McGowan (director); Julie Lipson (screenplay); Hermione Corfield, Jay Paulson, Sean O'Bryan, Micah Hauptman
# 2                                                                  Wilson Coneybeare (director/screenplay); Donald Sutherland, Vincent Kartheiser, Oliver Dennis, Paul Braunstein
# 3               Charles Martin Smith (director); W. Bruce Cameron (screenplay); Bryce Dallas Howard, Edward James Olmos, Alexandra Shipp, Ashley Judd, Jonah Haur-King, Wes Studi
# 4                                                                                    Neil Burger (director); Jon Hartmere (screenplay); Bryan Cranston, Kevin Hart, Nicole Kidman
#
#                         genres         director_name         actor_1_name
# 0      Horror Thriller Mystery          Adam Robitel       Taylor Russell
# 1  Thriller Drama Action Crime           Jen McGowan    Hermione Corfield
# 2                     Thriller     Wilson Coneybeare    Donald Sutherland
# 3       Drama Adventure Family  Charles Martin Smith  Bryce Dallas Howard
# 4                 Comedy Drama           Neil Burger       Bryan Cranston

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

df_2019.head()
# Out:
# <ipython-input-34-1bddbb0607ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
#               Title  \
# 0       Escape Room
# 1        Rust Creek
# 2  American Hangman
# 3  A Dog's Way Home
# 4        The Upside
#
#                                                                                                                                                                     Cast and crew  \
# 0  Adam Robitel (director); Bragi F. Schut, Maria Melnik (screenplay); Taylor Russell, Logan Miller, Deborah Ann Woll, Tyler Labine, Jay Ellis, Nik Dodani, Yorick van Wageningen
# 1                                                                 Jen McGowan (director); Julie Lipson (screenplay); Hermione Corfield, Jay Paulson, Sean O'Bryan, Micah Hauptman
# 2                                                                  Wilson Coneybeare (director/screenplay); Donald Sutherland, Vincent Kartheiser, Oliver Dennis, Paul Braunstein
# 3               Charles Martin Smith (director); W. Bruce Cameron (screenplay); Bryce Dallas Howard, Edward James Olmos, Alexandra Shipp, Ashley Judd, Jonah Haur-King, Wes Studi
# 4                                                                                    Neil Burger (director); Jon Hartmere (screenplay); Bryan Cranston, Kevin Hart, Nicole Kidman
#
#                         genres         director_name         actor_1_name  \
# 0      Horror Thriller Mystery          Adam Robitel       Taylor Russell
# 1  Thriller Drama Action Crime           Jen McGowan    Hermione Corfield
# 2                     Thriller     Wilson Coneybeare    Donald Sutherland
# 3       Drama Adventure Family  Charles Martin Smith  Bryce Dallas Howard
# 4                 Comedy Drama           Neil Burger       Bryan Cranston
#
#          actor_2_name
# 0        Logan Miller
# 1         Jay Paulson
# 2  Vincent Kartheiser
# 3  Edward James Olmos
# 4          Kevin Hart

# %%
def get_actor3(x):
    # Step 1: Split the string to remove everything before "screenplay); "
    parts = x.split("screenplay); ")

    # Step 2: Check if there are actors after the screenplay/director section
    if len(parts) > 1:
        actors = parts[-1].split(", ")  # Extract the actors part and split by commas
    else:
        return np.NaN  # Return NaN if no actors are present

    # Step 3: Check if there are at least three actors
    if len(actors) >= 3:
        return actors[2].strip()  # Return the third actor
    else:
        return np.NaN  # Return NaN if there are fewer than three actors

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

df_2019.head()
# Out:
#               Title  \
# 0       Escape Room
# 1        Rust Creek
# 2  American Hangman
# 3  A Dog's Way Home
# 4        The Upside
#
#                                                                                                                                                                     Cast and crew  \
# 0  Adam Robitel (director); Bragi F. Schut, Maria Melnik (screenplay); Taylor Russell, Logan Miller, Deborah Ann Woll, Tyler Labine, Jay Ellis, Nik Dodani, Yorick van Wageningen
# 1                                                                 Jen McGowan (director); Julie Lipson (screenplay); Hermione Corfield, Jay Paulson, Sean O'Bryan, Micah Hauptman
# 2                                                                  Wilson Coneybeare (director/screenplay); Donald Sutherland, Vincent Kartheiser, Oliver Dennis, Paul Braunstein
# 3               Charles Martin Smith (director); W. Bruce Cameron (screenplay); Bryce Dallas Howard, Edward James Olmos, Alexandra Shipp, Ashley Judd, Jonah Haur-King, Wes Studi
# 4                                                                                    Neil Burger (director); Jon Hartmere (screenplay); Bryan Cranston, Kevin Hart, Nicole Kidman
#
#                         genres         director_name         actor_1_name  \
# 0      Horror Thriller Mystery          Adam Robitel       Taylor Russell
# 1  Thriller Drama Action Crime           Jen McGowan    Hermione Corfield
# 2                     Thriller     Wilson Coneybeare    Donald Sutherland
# 3       Drama Adventure Family  Charles Martin Smith  Bryce Dallas Howard
# 4                 Comedy Drama           Neil Burger       Bryan Cranston
#
#          actor_2_name      actor_3_name
# 0        Logan Miller  Deborah Ann Woll
# 1         Jay Paulson      Sean O'Bryan
# 2  Vincent Kartheiser     Oliver Dennis
# 3  Edward James Olmos   Alexandra Shipp
# 4          Kevin Hart     Nicole Kidman

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['combination'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']
new_df19.head()
# Out:
#           director_name         actor_1_name        actor_2_name  \
# 0          Adam Robitel       Taylor Russell        Logan Miller
# 1           Jen McGowan    Hermione Corfield         Jay Paulson
# 2     Wilson Coneybeare    Donald Sutherland  Vincent Kartheiser
# 3  Charles Martin Smith  Bryce Dallas Howard  Edward James Olmos
# 4           Neil Burger       Bryan Cranston          Kevin Hart
#
#        actor_3_name                       genres       movie_title  \
# 0  Deborah Ann Woll      Horror Thriller Mystery       escape room
# 1      Sean O'Bryan  Thriller Drama Action Crime        rust creek
# 2     Oliver Dennis                     Thriller  american hangman
# 3   Alexandra Shipp       Drama Adventure Family  a dog's way home
# 4     Nicole Kidman                 Comedy Drama        the upside
#
#                                                                                           combination
# 0                   Taylor Russell Logan Miller Deborah Ann Woll Adam Robitel Horror Thriller Mystery
# 1                  Hermione Corfield Jay Paulson Sean O'Bryan Jen McGowan Thriller Drama Action Crime
# 2                       Donald Sutherland Vincent Kartheiser Oliver Dennis Wilson Coneybeare Thriller
# 3  Bryce Dallas Howard Edward James Olmos Alexandra Shipp Charles Martin Smith Drama Adventure Family
# 4                                    Bryan Cranston Kevin Hart Nicole Kidman Neil Burger Comedy Drama

# %%
frames = [new_df19,new_df18]

new_df = pd.concat(frames)
new_df.head(3)
# Out:
#        director_name       actor_1_name        actor_2_name      actor_3_name  \
# 0       Adam Robitel     Taylor Russell        Logan Miller  Deborah Ann Woll
# 1        Jen McGowan  Hermione Corfield         Jay Paulson      Sean O'Bryan
# 2  Wilson Coneybeare  Donald Sutherland  Vincent Kartheiser     Oliver Dennis
#
#                         genres       movie_title  \
# 0      Horror Thriller Mystery       escape room
# 1  Thriller Drama Action Crime        rust creek
# 2                     Thriller  american hangman
#
#                                                                           combination
# 0   Taylor Russell Logan Miller Deborah Ann Woll Adam Robitel Horror Thriller Mystery
# 1  Hermione Corfield Jay Paulson Sean O'Bryan Jen McGowan Thriller Drama Action Crime
# 2       Donald Sutherland Vincent Kartheiser Oliver Dennis Wilson Coneybeare Thriller

# %%
old_df = pd.read_csv('/content/df_movie_2.csv')
old_df.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                               movie_title  \
# 0                                                  avatar
# 1                pirates of the caribbean: at world's end
# 2                                                 spectre
# 3                                   the dark knight rises
# 4  star wars: episode vii - the force awakens
#
#                                                                combination
# 0   CCH Pounder Joel David Moore Wes Studi Action Adventure Fantasy Sci-Fi
# 1        Johnny Depp Orlando Bloom Jack Davenport Action Adventure Fantasy
# 2  Christoph Waltz Rory Kinnear Stephanie Sigman Action Adventure Thriller
# 3            Tom Hardy Christian Bale Joseph Gordon-Levitt Action Thriller
# 4                               Doug Walker Rob Walker unknown Documentary

# %%
frames = [new_df,old_df]

final_df = pd.concat(frames)
final_df.head(3)
# Out:
#        director_name       actor_1_name        actor_2_name      actor_3_name  \
# 0       Adam Robitel     Taylor Russell        Logan Miller  Deborah Ann Woll
# 1        Jen McGowan  Hermione Corfield         Jay Paulson      Sean O'Bryan
# 2  Wilson Coneybeare  Donald Sutherland  Vincent Kartheiser     Oliver Dennis
#
#                         genres       movie_title  \
# 0      Horror Thriller Mystery       escape room
# 1  Thriller Drama Action Crime        rust creek
# 2                     Thriller  american hangman
#
#                                                                           combination
# 0   Taylor Russell Logan Miller Deborah Ann Woll Adam Robitel Horror Thriller Mystery
# 1  Hermione Corfield Jay Paulson Sean O'Bryan Jen McGowan Thriller Drama Action Crime
# 2       Donald Sutherland Vincent Kartheiser Oliver Dennis Wilson Coneybeare Thriller

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.to_csv('/content/df_movie_3.csv',index=False)
